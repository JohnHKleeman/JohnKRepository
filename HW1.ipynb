# %% [markdown]
# ## Exploratory Data Analysis
# Exploratory Data Analysis (aka EDA) are a set of techniques typically applied before modeling and can help inform the development of more complex statistical models as well as draw key insights from the data. Exploratory techniques are  important for eliminating or supporting potential hypotheses. Use your newly acquired data slicing skills (Pandas) as well as your knowledge with plotting visualizations (matplotlib, seaborn) to bring your dataset to life.
#
# [IMBD Dataset](https://www.kaggle.com/deepmatrix/imdb-5000-movie-dataset)
#
# **Grading Rubric:**
# This homework will be graded by level of effort. Please be sure to draw atleast 3 to 5 conclusions from your EDA process which could potentially support or eliminate a potential hypothesis.
#
# **Submission:**
# Please follow the submission guidelines provided [at our student repo](https://github.com/ga-students/DS_DT_13_Students). I will demonstrate a sample homework submissiong during our lecture pertaining to version control.

# %%
import pandas as pd
import matplotlib as plt

# %%
# %time
# Out:
# Wall time: 0 ns

# %%
# !head -n3 ../datasets/hw1/movie_metadata.csv
# Out:
# 'head' is not recognized as an internal or external command,
# operable program or batch file.

# %%
data = pd.read_csv("../datasets/hw1/movie_metadata.csv")
data
# Out:
#                  color       director_name  num_critic_for_reviews  duration  \
# 0                Color       James Cameron                     723       178
# 1                Color      Gore Verbinski                     302       169
# 2                Color          Sam Mendes                     602       148
# 3                Color   Christopher Nolan                     813       164
# 4                  NaN         Doug Walker                     NaN       NaN
# 5                Color      Andrew Stanton                     462       132
# 6                Color           Sam Raimi                     392       156
# 7                Color        Nathan Greno                     324       100
# 8                Color         Joss Whedon                     635       141
# 9                Color         David Yates                     375       153
# 10               Color         Zack Snyder                     673       183
# ...

# %%
data.shape
# Out:
# (5043, 28)

# %%
data.head(10)
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                     723       178
# 1  Color     Gore Verbinski                     302       169
# 2  Color         Sam Mendes                     602       148
# 3  Color  Christopher Nolan                     813       164
# 4    NaN        Doug Walker                     NaN       NaN
# 5  Color     Andrew Stanton                     462       132
# 6  Color          Sam Raimi                     392       156
# 7  Color       Nathan Greno                     324       100
# 8  Color        Joss Whedon                     635       141
# 9  Color        David Yates                     375       153
#
#    director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                        0                     855   Joel David Moore
# 1                      563                    1000      Orlando Bloom
# 2                        0                     161       Rory Kinnear
# ...

# %%
data.tail(10)
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 5033  Color     Shane Carruth                     143        77
# 5034  Color  Neill Dela Llana                      35        80
# 5035  Color  Robert Rodriguez                      56        81
# 5036  Color   Anthony Vallone                     NaN        84
# 5037  Color      Edward Burns                      14        95
# 5038  Color       Scott Smith                       1        87
# 5039  Color               NaN                      43        43
# 5040  Color  Benjamin Roberds                      13        76
# 5041  Color       Daniel Hsia                      14       100
# 5042  Color          Jon Gunn                      43        90
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 5033                      291                       8      David Sullivan
# 5034                        0                       0     Edgar Tancangco
# ...

# %%
#Movie Data
#Possible targets could be Profit, Popularity, Critic Ratings, Gross Net, Best Bang For your Buck /Actor/Director/Genre/

# %%
#clean up the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
# color                        5024 non-null object
# director_name                4939 non-null object
# num_critic_for_reviews       4993 non-null float64
# duration                     5028 non-null float64
# director_facebook_likes      4939 non-null float64
# actor_3_facebook_likes       5020 non-null float64
# actor_2_name                 5030 non-null object
# actor_1_facebook_likes       5036 non-null float64
# gross                        4159 non-null float64
# genres                       5043 non-null object
# actor_1_name                 5036 non-null object
# movie_title                  5043 non-null object
# num_voted_users              5043 non-null int64
# cast_total_facebook_likes    5043 non-null int64
# actor_3_name                 5020 non-null object
# facenumber_in_poster         5030 non-null float64
# ...

# %%
data.genres
# Out:
# 0                         Action|Adventure|Fantasy|Sci-Fi
# 1                                Action|Adventure|Fantasy
# 2                               Action|Adventure|Thriller
# 3                                         Action|Thriller
# 4                                             Documentary
# 5                                 Action|Adventure|Sci-Fi
# 6                                Action|Adventure|Romance
# 7       Adventure|Animation|Comedy|Family|Fantasy|Musi...
# 8                                 Action|Adventure|Sci-Fi
# 9                        Adventure|Family|Fantasy|Mystery
# 10                                Action|Adventure|Sci-Fi
# 11                                Action|Adventure|Sci-Fi
# 12                                       Action|Adventure
# 13                               Action|Adventure|Fantasy
# 14                               Action|Adventure|Western
# 15                        Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
genres_type = pd.read_table("../datasets/hw1/movie_metadata.csv"}
# Out:
#   File "<ipython-input-12-72589a2ffadb>", line 1
#     genres_type = pd.read_table("../datasets/hw1/movie_metadata.csv"}
#                                                                     ^
# SyntaxError: invalid syntax

# %%
Sci_fi = 0  # counters for the genres
Crime = 0
Drama = 0
Comedy = 0 
Horror = 0
Thriller = 0
Docum = 0
Myst = 0
Action = 0
Adven = 0
Roma = 0
Hist = 0
Fam = 0
Fan = 0
Music = 0
Ani = 0
West = 0
War = 0
Bio = 0
Known = 0
Knowncheck = 0
Unknown = 0 # see if we have all the genres listed
All_genres = "Sci-Fi","Crime","Drama","Comedy","Horror","Thriller","Mystery","Documentary","Action","Adventure","Romance","History","Family","Fantasy","Music","Animation","Western","War","Biography"
Counter = len(data.genres)

for n in data.genres: # starting the process of seperating the data
        if "Sci-Fi" in n:
            Sci_fi += 1
            Known += 1
            #print n  used to get a cursory glance to see if i was missing anything
        if "Crime" in n:
            Crime += 1
            Known += 1
            #print n  used to get a cursory glance to see if i was missing anything
        if "Drama" in n:
            Drama += 1
            Known += 1
            #print n  used to get a cursory glance to see if i was missing anything
        if "Comedy" in n:
            Comedy += 1
            Known += 1
            #print n  used to get a cursory glance to see if i was missing anything
        if "Horror" in n:
            Horror += 1
            Known += 1
            #print n  used to get a cursory glance to see if i was missing anything
        if "Thriller" in n:
            Thriller += 1
            Known += 1
            #print n  used to get a cursory glance to see if i was missing anything
        if "Documentary" in n:
            Docum += 1
            Known += 1
            #print n  used to get a cursory glance to see if i was missing anything
        if "Mystery" in n:
            Myst += 1
            Known += 1
            #print n  used to get a cursory glance to see if i was missing anything
        if "Action" in n:
            Action += 1
            Known += 1
            #print n
        if "Adventure" in n:
            Adven += 1
            Known += 1
            #print n  used to get a cursory glance to see if i was missing anything
        if "Romance" in n:
            Roma += 1
            Known += 1
            #print n  used to get a cursory glance to see if i was missing anything
        if "History" in n:
            Hist += 1
            Known += 1
            #print n  used to get a cursory glance to see if i was missing anything
        if "Family" in n:
            Fam += 1
            Known += 1
            #print n  used to get a cursory glance to see if i was missing anything
        if "Fantasy" in n:
            Fan += 1
            Known += 1
            #print n  used to get a cursory glance to see if i was missing anything
        if "Music" in n:
            Music += 1
            Known += 1
            print n  #used to get a cursory glance to see if i was missing anything
        if "Musical" in n:
            Musical += 1
            
        if "Animation" in n:
            Ani += 1
            Known += 1
            #print n  used to get a cursory glance to see if i was missing anything
        if "Western" in n:
            West += 1
            Known += 1
            #print n  used to get a cursory glance to see if i was missing anything
        if "War" in n:
            War += 1
            Known += 1
            #print n  
        if "Biography" in n:
            Bio += 1
            Known += 1
            #print n  used to get a cursory glance to see if i was missing anything
        if any(c in n for c in All_genres):  
            Knowncheck += 1
        else:
            Unknown += 1
        
print Knowncheck

# %%
elif any(c in n for c in All_genres): 
            Counter -= 1
            print Counter
            if ("Sci-Fi" or "Crime" or "Drama" or "Comedy" or "Horror" or "Thriller" or "Documentary" or "Mystery" or "Action" 
        or "Adventure" or "Romance" or "History" or "Family" or "Fantasy" or "Music" or "Animation" or "Western"
        or "War" or "Biography") not in n:

# %%
data.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
data.isnull().sum() # looking for similarities in nulls
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
data.gross.describe()
# Out:
# count    4.159000e+03
# mean     4.846841e+07
# std      6.845299e+07
# min      1.620000e+02
# 25%      5.340988e+06
# 50%      2.551750e+07
# 75%      6.230944e+07
# max      7.605058e+08
# Name: gross, dtype: float64

# %%
data[data.gross > 300000000].director_name
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 3       Christopher Nolan
# 6               Sam Raimi
# 8             Joss Whedon
# 9             David Yates
# 10            Zack Snyder
# 13         Gore Verbinski
# 17            Joss Whedon
# 26          James Cameron
# 27          Anthony Russo
# 29        Colin Trevorrow
# 30             Sam Mendes
# 31              Sam Raimi
# 32            Shane Black
# 33             Tim Burton
# 36            Michael Bay
# 43            Lee Unkrich
# 45              James Wan
# 53            Michael Bay
# 54       Steven Spielberg
# 66      Christopher Nolan
# 69            Jon Favreau
# 78            Pete Docter
# 79            Jon Favreau
# 80            Jon Favreau
# 95             James Gunn
# 99          Peter Jackson
# 107          Chris Miller
# 112           Michael Bay
#               ...
# 202        Chris Columbus
# 205        Gore Verbinski
# 207      Francis Lawrence
# 236          George Lucas
# 237          George Lucas
# ...

# %%
(data.gross.isnull() & data.budget.isnull()).sum() # checking to see if there is direct connection between null gross and null budget
# Out:
# 224

# %%
data.budget.dropna()  #the budgets of the movies with na removed
# Out:
# 0       237000000
# 1       300000000
# 2       245000000
# 3       250000000
# 5       263700000
# 6       258000000
# 7       260000000
# 8       250000000
# 9       250000000
# 10      250000000
# 11      209000000
# 12      200000000
# 13      225000000
# 14      215000000
# 15      225000000
# 16      225000000
# 17      220000000
# 18      250000000
# 19      225000000
# 20      250000000
# 21      230000000
# 22      200000000
# 23      225000000
# 24      180000000
# 25      207000000
# 26      200000000
# 27      250000000
# 28      209000000
# 29      150000000
# 30      200000000
#           ...
# 5002        50000
# 5004        30000
# 5006        60000
# 5008       230000
# 5009        27000
# 5011        25000
# 5012     35000000
# 5013        24000
# 5015        23000
# 5016        25000
# 5017        22000
# 5018        20000
# 5020        17350
# 5021        15000
# 5022        15000
# 5023        15000
# 5024        20000
# 5025        10000
# 5026         4500
# ...

# %%
data.gross.dropna()-data.budget.dropna()
# Out:
# 0       523505847
# 1         9404152
# 2       -44925825
# 3       198130642
# 5      -190641321
# 6        78530303
# 7       -59192738
# 8       208991599
# 9        51956980
# 10       80249062
# 11       -8930592
# 12      -31631573
# 13      198032628
# 14     -125710090
# 15       66021565
# 16      -83385977
# 17      403279547
# 18       -8936125
# 19      -45979146
# 20        5108370
# 21       32030663
# 22      -94780265
# 23       33355354
# 24     -109916481
# 25       11051260
# 26      458672302
# 27      157197282
# 28     -143826840
# 29      502177271
# 30      104360277
#           ...
# 5006          NaN
# 5007          NaN
# 5008      2921130
# 5009       -18769
# 5011      2831622
# 5012    -24500032
# 5013          NaN
# 5015      1204508
# 5016          NaN
# 5017          NaN
# 5018          NaN
# 5020          NaN
# 5021       177467
# 5022          NaN
# 5023        61382
# 5024          NaN
# 5025       170483
# 5026       131507
# 5027       663780
# ...

# %%
 
data['profit'] = data.gross-data.budget # add a column for profit

# %%
data    #tada there is profit!
# Out:
#                  color       director_name  num_critic_for_reviews  duration  \
# 0                Color       James Cameron                     723       178
# 1                Color      Gore Verbinski                     302       169
# 2                Color          Sam Mendes                     602       148
# 3                Color   Christopher Nolan                     813       164
# 4                  NaN         Doug Walker                     NaN       NaN
# 5                Color      Andrew Stanton                     462       132
# 6                Color           Sam Raimi                     392       156
# 7                Color        Nathan Greno                     324       100
# 8                Color         Joss Whedon                     635       141
# 9                Color         David Yates                     375       153
# 10               Color         Zack Snyder                     673       183
# ...

# %%
data.profit.describe()
# Out:
# count    3.891000e+03
# mean     5.844717e+06
# std      2.261794e+08
# min     -1.221330e+10
# 25%     -1.026518e+07
# 50%      8.516360e+05
# 75%      2.475147e+07
# max      5.235058e+08
# Name: profit, dtype: float64

# %%
data.loc[:,['gross','budget','profit']] #checking to see if it worked
# Out:
#           gross     budget     profit
# 0     760505847  237000000  523505847
# 1     309404152  300000000    9404152
# 2     200074175  245000000  -44925825
# 3     448130642  250000000  198130642
# 4           NaN        NaN        NaN
# 5      73058679  263700000 -190641321
# 6     336530303  258000000   78530303
# 7     200807262  260000000  -59192738
# 8     458991599  250000000  208991599
# 9     301956980  250000000   51956980
# 10    330249062  250000000   80249062
# 11    200069408  209000000   -8930592
# 12    168368427  200000000  -31631573
# 13    423032628  225000000  198032628
# 14     89289910  215000000 -125710090
# 15    291021565  225000000   66021565
# 16    141614023  225000000  -83385977
# 17    623279547  220000000  403279547
# 18    241063875  250000000   -8936125
# 19    179020854  225000000  -45979146
# 20    255108370  250000000    5108370
# 21    262030663  230000000   32030663
# 22    105219735  200000000  -94780265
# 23    258355354  225000000   33355354
# ...

# %%
monetary_data = data.loc[:,['gross','budget','profit']]  #lets just work with this for now

# %%
monetary_data.describe()
# Out:
#               gross        budget        profit
# count  4.159000e+03  4.551000e+03  3.891000e+03
# mean   4.846841e+07  3.975262e+07  5.844717e+06
# std    6.845299e+07  2.061149e+08  2.261794e+08
# min    1.620000e+02  2.180000e+02 -1.221330e+10
# 25%    5.340988e+06  6.000000e+06 -1.026518e+07
# 50%    2.551750e+07  2.000000e+07  8.516360e+05
# 75%    6.230944e+07  4.500000e+07  2.475147e+07
# max    7.605058e+08  1.221550e+10  5.235058e+08

# %%
len(data) - len(monetary_data.dropna())  # curious how much data isnt being used if profit is what is being focused on
# Out:
# 1152

# %%
monetary_data.sort(columns='profit', axis=0, ascending=False)
# Out:
# C:\Users\j_coo\Anaconda2\envs\ClassProject\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   """Entry point for launching an IPython kernel.
#           gross     budget     profit
# 0     760505847  237000000  523505847
# 29    652177271  150000000  502177271
# 26    658672302  200000000  458672302
# 3024  460935665   11000000  449935665
# 3080  434949459   10500000  424449459
# 794   623279547  220000000  403279547
# 17    623279547  220000000  403279547
# 509   422783777   45000000  377783777
# 240   474544677  115000000  359544677
# 66    533316061  185000000  348316061
# 439   407999255   78000000  329999255
# 812   363024263   58000000  305024263
# 186   424645577  130000000  294645577
# 697   356784000   63000000  293784000
# 521   368049635   76000000  292049635
# 814   350123553   58800000  291323553
# 338   380838870   94000000  286838870
# 582   436471036  150000000  286471036
# ...

# %%
data[data.profit > 0].director_name
# Out:
# 0            James Cameron
# 1           Gore Verbinski
# 3        Christopher Nolan
# 6                Sam Raimi
# 8              Joss Whedon
# 9              David Yates
# 10             Zack Snyder
# 13          Gore Verbinski
# 15             Zack Snyder
# 17             Joss Whedon
# 20           Peter Jackson
# 21               Marc Webb
# 23           Peter Jackson
# 25           Peter Jackson
# 26           James Cameron
# 27           Anthony Russo
# 29         Colin Trevorrow
# 30              Sam Mendes
# 31               Sam Raimi
# 32             Shane Black
# 33              Tim Burton
# 34            Brett Ratner
# 35             Dan Scanlon
# 36             Michael Bay
# 37             Michael Bay
# 38               Sam Raimi
# 39               Marc Webb
# 40         Joseph Kosinski
# 43             Lee Unkrich
# 45               James Wan
#                ...
# 4931           John Carney
# 4936           Tobe Hooper
# 4941         Michael Moore
# ...

# %%
 data.loc[:,['profit','director_name']].sort(columns='profit', axis=0, ascending=False).dropna()  #Most profit attached to director
# Out:
# C:\Users\j_coo\Anaconda2\envs\ClassProject\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   """Entry point for launching an IPython kernel.
#            profit        director_name
# 0       523505847        James Cameron
# 29      502177271      Colin Trevorrow
# 26      458672302        James Cameron
# 3024    449935665         George Lucas
# 3080    424449459     Steven Spielberg
# 794     403279547          Joss Whedon
# 17      403279547          Joss Whedon
# 509     377783777         Roger Allers
# 240     359544677         George Lucas
# 66      348316061    Christopher Nolan
# 439     329999255            Gary Ross
# 812     305024263           Tim Miller
# 186     294645577     Francis Lawrence
# 697     293784000     Steven Spielberg
# 521     292049635        Pierre Coffin
# 814     291323553       Clint Eastwood
# 338     286838870       Andrew Stanton
# 582     286471036       Andrew Adamson
# ...

# %% [raw]
# d

# %%
director_datapos = data[data.profit > 0]
director_datamostprofit = director_datapos.loc[:,['profit','director_name']].sort(columns='profit', axis=0, ascending=False)
director_datamostprofit
# directors that have made a profit  learning how to use exceptions
# Out:
# C:\Users\j_coo\Anaconda2\envs\ClassProject\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#          profit       director_name
# 0     523505847       James Cameron
# 29    502177271     Colin Trevorrow
# 26    458672302       James Cameron
# 3024  449935665        George Lucas
# 3080  424449459    Steven Spielberg
# 794   403279547         Joss Whedon
# 17    403279547         Joss Whedon
# 509   377783777        Roger Allers
# 240   359544677        George Lucas
# 66    348316061   Christopher Nolan
# 439   329999255           Gary Ross
# 812   305024263          Tim Miller
# 186   294645577    Francis Lawrence
# 697   293784000    Steven Spielberg
# 521   292049635       Pierre Coffin
# 814   291323553      Clint Eastwood
# 338   286838870      Andrew Stanton
# 582   286471036      Andrew Adamson
# 339   283019252       Peter Jackson
# 1536  276625409    Richard Marquand
# 836   274691196     Robert Zemeckis
# ...

# %%
director_datamostprofit.sort(columns='director_name', axis=0, ascending=False)
# Out:
# C:\Users\j_coo\Anaconda2\envs\ClassProject\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   """Entry point for launching an IPython kernel.
#          profit          director_name
# 3678    1239558       Émile Gaudreault
# 4401   32885635            Zack Snyder
# 1759   32885635            Zack Snyder
# 10     80249062            Zack Snyder
# 709   145592590            Zack Snyder
# 15     66021565            Zack Snyder
# 4189   24281723             Zach Braff
# 4478    2406383         Youssef Delara
# 519   248505540          Yarrow Cheney
# 2481   15687528            Xavier Gens
# 2560    7713577            Woody Allen
# 3907    6515579            Woody Allen
# 2664    8089926            Woody Allen
# 3889   35200000            Woody Allen
# 1627   39816662            Woody Allen
# 2415   15404871            Woody Allen
# 221    42618434      Wolfgang Petersen
# 957    17823573      Wolfgang Petersen
# ...

# %%
director_data = data.loc[:,['profit','director_name']].sort(columns='profit', axis=0, ascending=False).dropna()
# director_datasum = director_data.groupby('director_name').sum() first attempt
director_datasum = director_data
director_datasum['profit_sum'] = director_datasum.groupby('director_name')['profit'].transform(sum)
director_df_profit_organized = director_datasum.loc[:,['profit_sum','director_name']].sort(columns='profit_sum', axis=0, ascending=False).drop_duplicates('director_name').head(40)
director_df_profit_organized
# Ranking of directors fom most profitable to least profitable. 
# possible questions not answered yet that need to be looked into:
# Are they becoming more or less profitable?
# Was this profit from a singular movie while most others were failures?
# Most profit does not necessarily mean higher rate of return on investment, could be that a lesser individual on the list gives
#              a better percentage return on investment
#consistent successes from inconsistent successes.
# Out:
# C:\Users\j_coo\Anaconda2\envs\ClassProject\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   """Entry point for launching an IPython kernel.
# C:\Users\j_coo\Anaconda2\envs\ClassProject\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   """
#       profit_sum            director_name
# 589   2486332231         Steven Spielberg
# 240   1386641480             George Lucas
# 291   1199625910            James Cameron
# 794   1000886628              Joss Whedon
# 385    941707624           Chris Columbus
# 2049   900969279            Peter Jackson
# 134    824275480               Tim Burton
# 96     808227576        Christopher Nolan
# 682    769381547              Jon Favreau
# 207    755501971         Francis Lawrence
# 528    644242537              Michael Bay
# 1784   642524555                Jay Roach
# ...
